# %% [markdown]
# ## Libraries used for EDA

# %%
import pandas as pd #data manipulation and analysis
import matplotlib.pyplot as plt #visualizations
import re

# %% [markdown]
# ## Overview of the Dataset

# %%
listings= pd.read_csv('/content/drive/MyDrive/Airbnb/Airbnb_original_data/listings2024.csv') #Load the dataset
listings.head() #Display few rows
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   31094   https://www.airbnb.com/rooms/31094  20240629155650   2024-06-30
# 1  262961  https://www.airbnb.com/rooms/262961  20240629155650   2024-06-30
# 2  263036  https://www.airbnb.com/rooms/263036  20240629155650   2024-06-30
# 3   32379   https://www.airbnb.com/rooms/32379  20240629155650   2024-06-30
# 4  263708  https://www.airbnb.com/rooms/263708  20240629155650   2024-06-30
#
#             source                                               name  \
# 0  previous scrape  Beautiful, spacious, central, renovated Penthouse
# 1      city scrape    192m2 FLAT+ 8m2 BALCONY IN CENTER NØRREBRO HOOD
# 2      city scrape                    Bright flat in central location
# 3      city scrape  155 m2 artist flat on Vesterbro, with 2 bathrooms
# 4      city scrape                  Urban garden on Vesterbro rooftop
#
#                                          description  \
# 0  Welcome to our home, we hope you will enjoy Wo...
# 1  If you are looking for a large apartment in ce...
# 2                                                NaN
# 3  You enter a narrow entrance and feel the good ...
# 4                                                NaN
#
#                                neighborhood_overview  \
# 0  What else is nearby?<br />To be honest, We thi...
# 1  TIME OUT - The world’s coolest neighbourhoods ...
# 2                                                NaN
# 3  Værnedamsvej area is super hip area, we call i...
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   129976  ...
# 1  https://a0.muscache.com/pictures/261aa506-7b13...  1379904  ...
# 2  https://a0.muscache.com/pictures/17770169/f1fb...  1232471  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...   140105  ...
# 4  https://a0.muscache.com/pictures/8ce36f40-ac59...  1383888  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.82                   4.80                4.53
# 1                        4.94                   4.89                4.53
# 2                        4.86                   4.81                4.67
# 3                        4.91                   4.89                4.71
# 4                        5.00                   4.67                4.00
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              1
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.11
# 1                                           0              0.24
# 2                                           0              0.14
# 3                                           0              0.49
# 4                                           0              0.02
#
# [5 rows x 75 columns]

# %%
print(listings.shape) #Understand the dimension of the dataset
# Out:
# (20909, 75)

# %%
print(listings.info()) #Understand the structure of the dataset: its dimensions, columns and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20909 entries, 0 to 20908
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            20909 non-null  int64
#  1   listing_url                                   20909 non-null  object
#  2   scrape_id                                     20909 non-null  int64
#  3   last_scraped                                  20909 non-null  object
#  4   source                                        20909 non-null  object
#  5   name                                          20909 non-null  object
#  6   description                                   20235 non-null  object
#  7   neighborhood_overview                         8984 non-null   object
#  8   picture_url                                   20909 non-null  object
#  9   host_id                                       20909 non-null  int64
#  10  host_url                                      20909 non-null  object
#  11  host_name                                     20908 non-null  object
#  12  host_since                                    20908 non-null  object
#  13  host_location                                 17480 non-null  object
#  14  host_about                                    8866 non-null   object
#  15  host_response_time                            14441 non-null  object
#  16  host_response_rate                            14441 non-null  object
#  17  host_acceptance_rate                          17161 non-null  object
#  18  host_is_superhost                             20685 non-null  object
#  19  host_thumbnail_url                            20908 non-null  object
#  20  host_picture_url                              20908 non-null  object
#  21  host_neighbourhood                            5417 non-null   object
#  22  host_listings_count                           20908 non-null  float64
#  23  host_total_listings_count                     20908 non-null  float64
#  24  host_verifications                            20908 non-null  object
#  25  host_has_profile_pic                          20908 non-null  object
#  26  host_identity_verified                        20908 non-null  object
#  27  neighbourhood                                 8984 non-null   object
#  28  neighbourhood_cleansed                        20909 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      20909 non-null  float64
#  31  longitude                                     20909 non-null  float64
#  32  property_type                                 20909 non-null  object
#  33  room_type                                     20909 non-null  object
#  34  accommodates                                  20909 non-null  int64
#  35  bathrooms                                     13660 non-null  float64
#  36  bathrooms_text                                20903 non-null  object
#  37  bedrooms                                      20300 non-null  float64
#  38  beds                                          13660 non-null  float64
#  39  amenities                                     20909 non-null  object
#  40  price                                         13596 non-null  object
#  41  minimum_nights                                20909 non-null  int64
#  42  maximum_nights                                20909 non-null  int64
#  43  minimum_minimum_nights                        20909 non-null  int64
#  44  maximum_minimum_nights                        20909 non-null  int64
#  45  minimum_maximum_nights                        20909 non-null  int64
#  46  maximum_maximum_nights                        20909 non-null  int64
#  47  minimum_nights_avg_ntm                        20909 non-null  float64
#  48  maximum_nights_avg_ntm                        20909 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              20437 non-null  object
#  51  availability_30                               20909 non-null  int64
#  52  availability_60                               20909 non-null  int64
#  53  availability_90                               20909 non-null  int64
#  54  availability_365                              20909 non-null  int64
#  55  calendar_last_scraped                         20909 non-null  object
#  56  number_of_reviews                             20909 non-null  int64
#  57  number_of_reviews_ltm                         20909 non-null  int64
#  58  number_of_reviews_l30d                        20909 non-null  int64
#  59  first_review                                  17689 non-null  object
#  60  last_review                                   17689 non-null  object
#  61  review_scores_rating                          17689 non-null  float64
#  62  review_scores_accuracy                        17665 non-null  float64
#  63  review_scores_cleanliness                     17665 non-null  float64
#  64  review_scores_checkin                         17665 non-null  float64
#  65  review_scores_communication                   17665 non-null  float64
#  66  review_scores_location                        17664 non-null  float64
#  67  review_scores_value                           17664 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              20909 non-null  object
#  70  calculated_host_listings_count                20909 non-null  int64
#  71  calculated_host_listings_count_entire_homes   20909 non-null  int64
#  72  calculated_host_listings_count_private_rooms  20909 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   20909 non-null  int64
#  74  reviews_per_month                             17689 non-null  float64
# dtypes: float64(20), int64(21), object(34)
# memory usage: 12.0+ MB
# None

# %% [markdown]
# ## Price Variable

# %%
listings['price'].head() #few rows of price variable
# Out:
# 0          NaN
# 1    $1,865.00
# 2      $905.00
# 3    $1,865.00
# 4    $1,800.00
# Name: price, dtype: object

# %%
listings['price'] = listings['price'].str.replace(r'[$,]', '', regex=True).astype(float) #removing dollar signs and commas and converting it to float

# %%
# What is the distribution of 'price'?
print(listings['price'].describe())
# Out:
# count     13596.000000
# mean       1372.736320
# std        1403.526364
# min         100.000000
# 25%         900.000000
# 50%        1186.000000
# 75%        1563.750000
# max      100000.000000
# Name: price, dtype: float64

# %%
# 'price' column is in dkk currency and not us dollars or eur.
listings.rename(columns={'price': 'price_dkk'}, inplace=True)

# %%
lower_threshold = 300 #setting minimum price threshold of 300 DKK (~ 40€) to exclude extremely low prices.
upper_threshold = 37303 #setting maximum price threshold of 37303 DKK (~ 5000€) to exclude extremely high prices.

# setting prices below 'lower_threshold' to 'lower_threshold' and above 'upper_threshold' to 'upper_threshold'.
listings['price_dkk'] = listings['price_dkk'].clip(lower= lower_threshold, upper= upper_threshold)
print(listings['price_dkk'].describe())
# Out:
# count    13596.000000
# mean      1365.990953
# std       1064.872166
# min        300.000000
# 25%        900.000000
# 50%       1186.000000
# 75%       1563.750000
# max      37303.000000
# Name: price_dkk, dtype: float64

# %% [markdown]
# ## Host Response Rate and Acceptance Rate

# %%
listings[['host_response_rate', 'host_acceptance_rate']].head() #few rows
# Out:
#   host_response_rate host_acceptance_rate
# 0                NaN                  NaN
# 1                NaN                 100%
# 2               100%                   0%
# 3               100%                 100%
# 4                90%                   0%

# %%
listings['host_response_rate'] = listings['host_response_rate'].str.replace(r'%', '', regex=True).astype(float)/100 #removing % sign and converting it to float
listings['host_acceptance_rate'] = listings['host_acceptance_rate'].str.replace(r'%', '', regex=True).astype(float)/100 #removing % sign and converting it to float
listings[['host_response_rate', 'host_acceptance_rate']].head() #few rows
# Out:
#    host_response_rate  host_acceptance_rate
# 0                 NaN                   NaN
# 1                 NaN                   1.0
# 2                 1.0                   0.0
# 3                 1.0                   1.0
# 4                 0.9                   0.0

# %% [markdown]
# ## Data Type Adjustment

# %%
listings['last_scraped'] = pd.to_datetime(listings['last_scraped']) #'last_scraped' column to datetime format
listings['host_since'] = pd.to_datetime(listings['host_since']) #'host_since' column to datetime format
listings['calendar_last_scraped'] = pd.to_datetime(listings['calendar_last_scraped']) #'calendar_last_scraped' column to datetime format
listings['first_review'] = pd.to_datetime(listings['first_review']) #'first_review' column to datetime format
listings['last_review'] = pd.to_datetime(listings['last_review']) #'last_review' column to datetime format

listings['host_is_superhost'] = listings['host_is_superhost'].map({'t': True, 'f': False}) #from 't' and 'f' to boolean (True/False)
listings['host_has_profile_pic'] = listings['host_has_profile_pic'].map({'t': True, 'f': False}) #from 't' and 'f' to boolean (True/False)
listings['host_identity_verified'] = listings['host_identity_verified'].map({'t': True, 'f': False}) #from 't' and 'f' to boolean (True/False)
listings['has_availability'] = listings['has_availability'].map({'t': True, 'f': False}) #from 't' and 'f' to boolean (True/False)
listings['instant_bookable'] = listings['instant_bookable'].map({'t': True, 'f': False}) #from 't' and 'f' to boolean (True/False)

# %% [markdown]
# ## Handling Missing Values

# %%
print(listings.isnull().sum()) #checking for missing values
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3220
# Length: 75, dtype: int64

# %%
listings.drop(['neighbourhood_group_cleansed', 'calendar_updated', 'license'], axis=1, inplace=True) #these variables only contains missing values

# %%
listings['beds'] = listings['beds'].fillna(listings['bedrooms']) #set null values in 'beds' with the corresponding values from 'bedrooms' (hypothesis: if a listing has 2 bedrooms, it has for sure at least 2 beds)

# %% [markdown]
# ## Exploring Individual Variables

# %%
print(listings['neighbourhood_cleansed'].unique())
# Out:
# ['Vesterbro-Kongens Enghave' 'Nrrebro' 'Amager st' 'sterbro' 'Indre By'
#  'Bispebjerg' 'Amager Vest' 'Valby' 'Frederiksberg' 'Vanlse'
#  'Brnshj-Husum']

# %%
neighbourhood_corrections = {
    "Amager st": "Amager Øst",       # From "Amager st" to "Amager Øst"
    "Brnshj-Husum": "Brønshøj-Husum", # From "Brnshj–Husum" to "Brønshøj-Husum"
    "Nrrebro": "Nørrebro",            # From "Nrrebro" to "Nørrebro"
    "sterbro": "Østerbro",           # From "sterbro" to "Østerbro"
    "Vanlse": "Vanløse"              # From "Vanlse" to "Vanløse"
}
listings['neighbourhood_cleansed'] = listings['neighbourhood_cleansed'].replace(neighbourhood_corrections) #rename values in 'neighbourhood_cleansed' column

# %%
print(listings['neighbourhood_cleansed'].unique())
# Out:
# ['Vesterbro-Kongens Enghave' 'Nørrebro' 'Amager Øst' 'Østerbro' 'Indre By'
#  'Bispebjerg' 'Amager Vest' 'Valby' 'Frederiksberg' 'Vanløse'
#  'Brønshøj-Husum']

# %%
print(listings['neighbourhood'].unique())
# Out:
# ['Copenhagen, Capital Region of Denmark, Denmark' nan
#  'Copenhagen, V, Denmark'
#  'Frederiksberg, Capital Region of Denmark, Denmark' 'Copenhagen, Denmark'
#  'Copenhagen, Hovedstaden, Denmark' 'Valby, Denmark'
#  'Frederiksberg, Denmark' 'Valby, Capital Region of Denmark, Denmark'
#  'København Ø, Capital Region of Denmark, Denmark'
#  'Kobenhavn V, Capital Region of Denmark, Denmark'
#  'Hellerup, Capital Region of Denmark, Denmark'
#  'Bronshoj, Capital Region of Denmark, Denmark' 'København S, Denmark'
#  'Vanløse, Capital Region of Denmark, Denmark'
#  'Brønshøj, Capital Region of Denmark, Denmark' 'københavn V, Denmark'
#  'kbh, Hovedstaden, Denmark' 'Copenhagen, Danmark, Denmark'
#  'Copenhagen, S, Denmark'
#  'Copenhagen , Capital Region of Denmark, Denmark'
#  'Copenhagen, Region Zealand, Denmark' 'Copenhagen V, Denmark'
#  'Copenhagen , Copenhagen, Denmark'
#  'Copenhagen N.W, Capital Region of Denmark, Denmark'
#  'Copenhagen N, Denmark' 'Søborg, Denmark' 'Copenhagen , Denmark'
#  'Copenhagen NV, Denmark'
#  'Frederiksberg C, Capital Region of Denmark, Denmark'
#  'Copenhagen V, Capital Region of Denmark, Denmark'
#  'Copenhagen, København, Denmark' 'København V, Denmark'
#  'Copenhagen, Islands Brygge, Sjælland, Denmark' 'Vanløse, Denmark'
#  'Brønshøj, København, Capital Region of Denmark, Denmark'
#  'Copenhagen, Vesterbro, Denmark' 'Copenhagen East, Denmark'
#  'Copenhagen, Sjælland, Denmark'
#  'København V, Capital Region of Denmark, Denmark'
#  'Valby, Copenhagen, Denmark' 'Hellerup, Denmark'
#  'Frederiksberg C, Copenhagen, Denmark' 'Frederiksberg C, Denmark'
#  'Frederiksberg-C, Denmark' 'Copenhagen S., Denmark'
#  'Copenaghen V, Capital Region of Denmark, Denmark'
#  'København Ø, Zealand, Denmark' 'Copenhagen, Østerbro, Denmark'
#  'Copenhagen, La Rioja Province, Denmark' 'Copenhagen, N, Denmark'
#  'København V, København, Denmark' 'København NV, Sealand, Denmark'
#  'Copenhagen, K, Denmark' 'Frederiksberg, København, Denmark'
#  'Copenhagen, Nørrebro, Denmark' 'valby, Denmark'
#  'Copenhagen, Ingen, Denmark' 'Copenhagen S, Denmark'
#  'Copenhagen, Cph, Denmark' 'Copenhagen, ., Denmark'
#  'Copenhagen, Dk, Denmark' 'Copenhagen S , Denmark'
#  'København N, N, Denmark' 'Copenhagen, England, Denmark'
#  'København Ø, Denmark' 'Copenhagen, CPH, Denmark'
#  'Frederiksberg, Hovedstaden, Denmark' 'Copenhagen v, Danmark, Denmark'
#  'Copenhagen V., Denmark' 'København N, København, Denmark'
#  'København K, Denmark' 'Denmark' 'Copenhagen , N, Denmark'
#  'København v, Denmark' 'Frederiksberg, Andalusia, Denmark'
#  'Frederiksberg, Danmark, Denmark' 'Frederiksberg,  , Denmark'
#  'Danmark., Denmark' 'København Ø, Hovedstaden, Denmark'
#  'KøbenhavnV,  , Denmark' 'Brønshøj ,  , Denmark'
#  'Copenhagen, Københavns kommune, Denmark' 'Copenhagen, Vanløse, Denmark'
#  'Kbh V , Danmark, Denmark' 'Valby, København, Denmark'
#  'Frederiksberg C., Denmark' 'Copenhagen C, Denmark' 'Nørrebro, Denmark'
#  'Copenhagen, DK, Denmark' 'København V, DK, Denmark'
#  'Copenhagen, Faro, Denmark' 'Copenhagen Ø, Denmark'
#  'København N, Denmark' 'Copenhagen,  , Denmark'
#  'Frederiksberg, Copenhagen, Denmark' 'Brønshøj, Denmark'
#  'Copenhagen, Kbh, Denmark' 'Copenhagen, Østerbro- Oesterbro, Denmark'
#  'Copenhagen, S., Denmark' 'københavn, Valby, Denmark'
#  'Copenhagen,   , Denmark' '2150, Danmark, Denmark'
#  'Copenhagen, Copenhagen S, Denmark' 'Copenhagen, Frederiksberg, Denmark'
#  'Copenhagen, Ø, Denmark' 'Vesterbro, Copenhagen, Denmark'
#  'København N, Hovedstaden, Denmark'
#  'Griffenfeldsgade, Number 43, ground floor, Copenhagen, Region Hovedstaden, 2200, Denmark, Denmark'
#  'Frederiksberg C, Dk, Denmark' 'København , V, Denmark'
#  'Copenhagen, Central Denmark Region, Denmark'
#  'Frederiksberg, Kbh, Denmark' 'København SV,, Denmark'
#  'Copenhagen, Kbh NV, Denmark' 'Copenhagen , Danmark, Denmark'
#  'Copenhagen, Capital Region, Denmark' 'Copenhagen, NV, Denmark'
#  'København V., Denmark' 'København SV, Denmark'
#  'Frederiksberg C, Hovedstaden, Denmark' 'Frederiksberg, DK, Denmark'
#  'København V, Dk, Denmark' 'Copenhagen, Valby, Denmark'
#  'Copenhagen, EU, Denmark' 'Copenhagen, --, Denmark'
#  'Copenhagen, KBH, Denmark' 'Frederiksberg, Dk, Denmark'
#  'København K,   , Denmark' '2500, København, Denmark'
#  ' Copenhagen,  Zealand, Denmark' 'Valby, DK, Denmark'
#  'Copenhagen, Zealand, Denmark' 'Frederiksberg, ., Denmark'
#  'Copenhagen, Sv, Denmark' 'København, DK, København, Denmark'
#  'København NV, København, Denmark' 'Copenhagen, -, Denmark'
#  'Frederiksberg C, Capital Area, Denmark' 'Copenhagen, n, Denmark'
#  'Copenhagen, Región Metropolitana, Denmark' 'København N, -, Denmark'
#  'Copenhagen, København K, Denmark' 'København , København, Denmark'
#  'Copenhagen, Xxx, Denmark' 'København N , Nørrebro, Denmark'
#  'Copenhagen, Nv, Denmark' 'Copenhagen k, Hovedstaden, Denmark'
#  'Amager, Hordaland, Denmark' 'Copenhagen , Hovedstaden, Denmark'
#  'København Ø, DK, Denmark' 'Copenhagen, Sundby, Denmark'
#  'København S, Hovedstaden, Denmark' 'Copenhagen, københavn, Denmark'
#  ' København V, Denmark' 'Frederiksberg C, Copenhagen Region, Denmark'
#  'Copenhagen, No, Denmark' 'København N, Nørrebro, Denmark'
#  'Vesterbro , København, Denmark' 'Copenhagen, Amager, Denmark'
#  'København V , Danmark, Denmark' 'Copenhagen, Copenhagen N., Denmark'
#  'Frederiksberg, 2000, Denmark' '2000 Frederiksberg, Denmark'
#  'Copenhagen, Hovedstatens, Denmark' 'København, Valby, Denmark'
#  'Hellerup, VA, Denmark' 'København s, Hovedstaden, Denmark'
#  'København V, København , Denmark' 'K, Denmark'
#  'Copenhagen S, Capital Region, Denmark'
#  'København S, Region Hovedstaden, Denmark'
#  'Copenhagen, Niedersachsen, Denmark'
#  'Copenhagen - Frederiksberg, Denmark'
#  'Frederiksberg, Île-de-France, Denmark' 'Copenhagen, Kbh V, Denmark'
#  'Copenhagen, 12, Denmark' 'vanløse, Copenhagen, Denmark'
#  'Østerbro, Denmark' 'Copenhagen, Buenos Aires, Denmark'
#  'Vesterbro København (Copenhagen), Denmark'
#  'Copenhagen, Hovendstaden, Denmark' 'København k, Sjælland, Denmark'
#  'København ø, Denmark' 'Frederiksberg C, Danmark, Denmark'
#  'Vanløse, København, Denmark' 'Copenhagen V, københavn, Denmark'
#  'København V , Denmark' 'Vanløse , København, Denmark' 'Tårnby, Denmark'
#  'København SV, København, Denmark' 'Nørrebro, København, Denmark'
#  'København., Denmark' 'København , Denmark' 'Vesterbro, Denmark'
#  'Copenhagen S, Copenhagen, Denmark' 'Copenhagen, Storkøbenhavn, Denmark'
#  'Copenhagen N, Hovedstaten, Denmark'
#  'Copenhagen, København, Denmark, Denmark' 'København S , Denmark'
#  'Dyssegård, Denmark' 'Copenhagen, Nørrebro, Copenhagen, Denmark'
#  'Valby, Hovedstaden, Denmark' 'Frederiksberg, Sealand, Denmark'
#  'Copenhagen, 2300, Denmark' 'København (Nordhavn), Denmark'
#  'København sv, Denmark' 'København k, Denmark' 'Copenhagen SV, Denmark'
#  'Copenhagen,  Østerbro, Denmark' ' Copenhagen S, Copenhagen, Denmark'
#  'Vanløse, Københavns kommune, Denmark'
#  'Copenhagen, Capital region, Denmark' 'Copenhagen, Marche, Denmark'
#  ' Copenhagen, Hovedstaden, Denmark' ' Copenhagen, Denmark'
#  'Copenhagen, Øresund, Denmark'
#  "Copenhagen, Provence-Alpes-Côte d'Azur, Denmark"
#  'København K, København, Denmark' 'Copenhagen,  Copenhagen V, Denmark'
#  ' Copenhagen SV, Denmark' 'Copenhagen, Copenhagen, Sjælland, Denmark'
#  'Copenhagen, København , Denmark' 'Rødovre, Denmark'
#  'Frederiksberg, Frederiksberg , Denmark']

# %%
# 'neighbourhood' contains information already represented (and improved) in neighborhood_cleansed
# so keeping it would be redundant
listings.drop('neighbourhood', axis=1, inplace=True)

# %%
listings[['bathrooms', 'bathrooms_text']].head() #few rows
# Out:
#    bathrooms bathrooms_text
# 0        NaN      1.5 baths
# 1        1.5      1.5 baths
# 2        0.0        0 baths
# 3        2.0        2 baths
# 4        1.0         1 bath

# %%
def extract_numbers(text):
    if pd.notnull(text):  #if text is not null
        if re.search(r'\d+(\.\d+)?', text): #if find int or float numbers
            return float(re.search(r'\d+(\.\d+)?', text).group(0))  #return number as a float
    return None  #return None if text is null or does not contain numbers

listings['bathrooms'] = listings['bathrooms'].fillna(listings['bathrooms_text'].apply(extract_numbers)) #fill null values of bathrooms with numbers in bathrooms_text

# %%
listings[['bathrooms', 'bathrooms_text']].head() #few rows
# Out:
#    bathrooms bathrooms_text
# 0        1.5      1.5 baths
# 1        1.5      1.5 baths
# 2        0.0        0 baths
# 3        2.0        2 baths
# 4        1.0         1 bath

# %%
print(listings['bathrooms_text'].unique())
# Out:
# ['1.5 baths' '0 baths' '2 baths' '1 bath' '1 shared bath' '3 baths'
#  '1 private bath' '2.5 baths' 'Half-bath' nan 'Shared half-bath'
#  'Private half-bath' '1.5 shared baths' '3.5 baths' '2 shared baths'
#  '5 baths' '0 shared baths' '4 baths' '2.5 shared baths' '3 shared baths'
#  '8 baths']

# %%
listings['is_bathroom_shared'] = listings['bathrooms_text'].str.contains('shared', case=False) #if "shared" in "bathroom_text" then "is_bathroom_shared" = True, else False

# %%
#get a numeric summary of all the numeric variables, is it everything ok?
numeric_summary = listings.describe()

print(numeric_summary.iloc[:, 0:15])
print(numeric_summary.iloc[:, 15:30])
print(numeric_summary.iloc[:, 30:46])
# Out:
#                  id     scrape_id                   last_scraped  \
# count  2.090900e+04  2.090900e+04                          20909
# mean   5.137813e+17  2.024063e+13  2024-06-29 16:49:50.329523200
# min    3.109400e+04  2.024063e+13            2024-06-29 00:00:00
# 25%    3.140450e+07  2.024063e+13            2024-06-29 00:00:00
# 50%    6.452861e+17  2.024063e+13            2024-06-30 00:00:00
# 75%    9.441256e+17  2.024063e+13            2024-06-30 00:00:00
# max    1.189116e+18  2.024063e+13            2024-06-30 00:00:00
# std    4.737075e+17  1.914108e+00                            NaN
#
#             host_id                     host_since  host_response_rate  \
# count  2.090900e+04                          20908        14441.000000
# mean   1.442690e+08  2016-11-19 18:39:56.785919488            0.898103
# min    5.130000e+02            2008-06-27 00:00:00            0.000000
# 25%    1.739651e+07            2014-07-06 00:00:00            1.000000
# 50%    6.431141e+07            2016-03-30 00:00:00            1.000000
# 75%    2.097030e+08            2018-08-18 06:00:00            1.000000
# max    5.862358e+08            2024-06-28 00:00:00            1.000000
# std    1.687214e+08                            NaN            0.236495
#
#        host_acceptance_rate  host_listings_count  host_total_listings_count  \
# count          17161.000000         20908.000000               20908.000000
# mean               0.683096             5.942606                  12.671992
# min                0.000000             1.000000                   1.000000
# 25%                0.460000             1.000000                   1.000000
# 50%                0.770000             1.000000                   1.000000
# 75%                1.000000             1.000000                   2.000000
# max                1.000000           667.000000                1972.000000
# std                0.323748            32.713862                  84.689161
#
#            latitude     longitude  accommodates     bathrooms      bedrooms  \
# count  20909.000000  20909.000000  20909.000000  20850.000000  20300.000000
# mean      55.680567     12.558550      3.336315      1.097410      1.622660
# min       55.615660     12.454000      1.000000      0.000000      0.000000
# 25%       55.666280     12.540730      2.000000      1.000000      1.000000
# 50%       55.681930     12.555170      3.000000      1.000000      1.000000
# 75%       55.696041     12.580508      4.000000      1.000000      2.000000
# max       55.732470     12.639720     16.000000      8.000000      8.000000
# std        0.019127      0.031304      1.644905      0.308649      0.895923
#
#                beds
# count  20303.000000
# mean       1.663941
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       14.000000
# std        1.229262
#           price_dkk  minimum_nights  maximum_nights  minimum_minimum_nights  \
# count  13596.000000    20909.000000    20909.000000            20909.000000
# mean    1365.990953        4.475680      352.519154                3.965517
# min      300.000000        1.000000        1.000000                1.000000
# 25%      900.000000        2.000000       20.000000                2.000000
# 50%     1186.000000        3.000000      365.000000                3.000000
# 75%     1563.750000        4.000000      365.000000                4.000000
# max    37303.000000     1111.000000     1125.000000             1111.000000
# std     1064.872166       16.259901      412.974973               14.410826
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count            20909.000000            20909.000000            20909.000000
# mean                 4.932230              422.606581              438.244536
# min                  1.000000                1.000000                1.000000
# 25%                  2.000000               21.000000               21.000000
# 50%                  3.000000              365.000000              365.000000
# 75%                  5.000000             1125.000000             1125.000000
# max               1111.000000             1125.000000             1125.000000
# std                 16.106725              450.996552              455.585215
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  \
# count            20909.000000            20909.000000     20909.000000
# mean                 4.540069              430.315749         6.965900
# min                  1.000000                1.000000         0.000000
# 25%                  2.000000               21.000000         0.000000
# 50%                  3.000000              365.000000         2.000000
# 75%                  4.000000             1125.000000        12.000000
# max               1111.000000             1125.000000        30.000000
# std                 15.405177              448.994259         8.976972
#
#        availability_60  availability_90  availability_365  \
# count     20909.000000     20909.000000      20909.000000
# mean         12.150462        18.859008         84.906787
# min           0.000000         0.000000          0.000000
# 25%           0.000000         0.000000          0.000000
# 50%           5.000000         7.000000         21.000000
# 75%          18.000000        27.000000        158.000000
# max          60.000000        90.000000        365.000000
# std          16.469767        25.642407        111.071142
#
#                calendar_last_scraped  number_of_reviews
# count                          20909       20909.000000
# mean   2024-06-29 16:49:50.329523200          17.534841
# min              2024-06-29 00:00:00           0.000000
# 25%              2024-06-29 00:00:00           2.000000
# 50%              2024-06-30 00:00:00           7.000000
# 75%              2024-06-30 00:00:00          18.000000
# max              2024-06-30 00:00:00        1972.000000
# std                              NaN          41.693636
#        number_of_reviews_ltm  number_of_reviews_l30d  \
# count           20909.000000            20909.000000
# mean                5.098092                0.626955
# min                 0.000000                0.000000
# 25%                 0.000000                0.000000
# 50%                 2.000000                0.000000
# 75%                 6.000000                1.000000
# max               758.000000               21.000000
# std                11.672984                1.328418
#
#                         first_review                    last_review  \
# count                          17689                          17689
# mean   2021-04-18 12:12:05.332127488  2023-09-08 18:44:47.636384256
# min              2010-07-25 00:00:00            2013-01-03 00:00:00
# 25%              2019-04-20 00:00:00            2023-07-27 00:00:00
# 50%              2022-07-16 00:00:00            2024-04-07 00:00:00
# 75%              2023-07-31 00:00:00            2024-06-14 00:00:00
# max              2024-06-29 00:00:00            2024-06-29 00:00:00
# std                              NaN                            NaN
#
#        review_scores_rating  review_scores_accuracy  \
# count          17689.000000            17665.000000
# mean               4.832067                4.848821
# min                1.000000                1.000000
# 25%                4.750000                4.790000
# 50%                4.920000                4.930000
# 75%                5.000000                5.000000
# max                5.000000                5.000000
# std                0.258608                0.248738
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               17665.000000           17665.000000
# mean                    4.707408               4.880881
# min                     1.000000               1.000000
# 25%                     4.570000               4.830000
# 50%                     4.820000               4.970000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
# std                     0.371739               0.219335
#
#        review_scores_communication  review_scores_location  \
# count                 17665.000000            17664.000000
# mean                      4.917725                4.840928
# min                       1.000000                1.000000
# 25%                       4.900000                4.760000
# 50%                       5.000000                4.920000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
# std                       0.191054                0.233053
#
#        review_scores_value  calculated_host_listings_count  \
# count         17664.000000                    20909.000000
# mean              4.724537                        4.659572
# min               1.000000                        1.000000
# 25%               4.620000                        1.000000
# 50%               4.780000                        1.000000
# 75%               5.000000                        1.000000
# max               5.000000                      239.000000
# std               0.308463                       26.246421
#
#        calculated_host_listings_count_entire_homes  \
# count                                 20909.000000
# mean                                      4.458415
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                     239.000000
# std                                      26.226017
#
#        calculated_host_listings_count_private_rooms  \
# count                                  20909.000000
# mean                                       0.195849
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       16.000000
# std                                        0.865031
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 20909.000000       17689.000000
# mean                                      0.004209           0.776318
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.190000
# 50%                                       0.000000           0.420000
# 75%                                       0.000000           0.930000
# max                                       3.000000          42.500000
# std                                       0.098688           1.124821

# %%
# Corrections to strings

listings['description'] = listings['description'].str.replace(r'<br\s*/?>', ' ', regex=True)
listings['description'] = listings['description'].str.replace(r'\s+', ' ', regex=True)

listings['neighborhood_overview'] = listings['neighborhood_overview'].str.replace(r'<br\s*/?>', ' ', regex=True)
listings['neighborhood_overview'] = listings['neighborhood_overview'].str.replace(r'\s+', ' ', regex=True)

listings['host_about'] = listings['host_about'].str.replace(r'<br\s*/?>', ' ', regex=True)
listings['host_about'] = listings['host_about'].str.replace(r'\s+', ' ', regex=True)

# %%
listings.to_csv('/content/drive/MyDrive/Airbnb/Airbnb_cleaned_csvs/listings_cleaned_with_missing_prices.csv', index=False)
